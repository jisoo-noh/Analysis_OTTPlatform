# %%
import pandas as pd

# %%
pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.netflix.mediaclient',
    sleep_milliseconds=0,
    lang='ko',
    country='kr',
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
)

# %%
len(result)
# Out:
# 21860

# %%
result
# Out:
# [{'at': datetime.datetime(2022, 7, 15, 14, 13, 22),
#   'content': '다양한 콘텐츠들을 오랫동안 계속 볼 수 있다는 점이 최고입니다. 결코 만만치 않은 가격일 수 있지만 한 번 결제하고 나면 일주일까지는 환불도 되고 한 달은 꽤 기니까 편안하게 즐길 수 있습니다. 인터랙티브라는 꽤나 흥미로운 것도 있습니다. 하지만 없는 콘텐츠도 많고 인터랙티브 콘텐츠를 볼 때는 이전 선택지로 돌아가기라는게 떠서 불편합니다. 가격도 비싼 편입니다.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '8.31.1 build 14 50243',
#   'reviewId': '610fdaa8-a86e-4761-bcec-66ab4e4a2cc4',
#   'score': 3,
#   'thumbsUpCount': 99,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucolchALUcA8wRTiOAGXUAVXawtDuhx0UlDuKYMuBA',
#   'userName': 'me'},
#  {'at': datetime.datetime(2022, 6, 21, 0, 31, 49),
#   'content': "미드, 영화 보면서 영어공부용으로 잘 사용하고 있습니다. 다만, 모바일에서 뒤로가기가 10초 밖에 안 되는 점이 불편합니다. 그래서 '곰플레이어'처럼 뒤로가기를 1초, 3초, 5초 등으로 세세하게 설정 가능했으면 좋겠습니다. 혹은 'KMPlayer' 어플처럼 손가락으로 드래그하면 몇초~몇십초 전으로 뒤로가기 가능하게끔 업데이트되면 좋을 듯합니다. 그러면 넷플릭스로 미드, 영화 보면서 저 포함 영어공부 하는 분들이나 일반 시청자들한테도 굉장히 큰 도움이 될 것 같습니다. 감사합니다.",
#   'repliedAt': None,
#   'replyContent': None,
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(result)
df = df.drop(columns=['userImage','replyContent','repliedAt','reviewId',
            'thumbsUpCount','reviewCreatedVersion'])
# df = df.drop(columns='replyContent')
# df = df.drop(columns='repliedAt')
# df= df.drop(columns='reviewId')
# df = df.drop(columns='thumbsUpCount')
# df = df.drop(columns='reviewCreatedVersion')

# %%
nef = df
nef.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21860 entries, 0 to 21859
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   userName  21860 non-null  object
#  1   content   21859 non-null  object
#  2   score     21860 non-null  int64
#  3   at        21860 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 683.2+ KB

# %%
nef.to_csv('C:/Users/USER/Desktop/project/play_netflix.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-9d092bb55166> in <module>()
# ----> 1 nef.to_csv('C:/Users/USER/Desktop/project/play_netflix.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ...

# %%
# 디즈니
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.disney.disneyplus',
    sleep_milliseconds=0,
    lang='ko',
    country='kr',
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
)

# %%
disney = pd.DataFrame(result)
disney = disney.drop(columns=['userImage','replyContent','repliedAt','reviewId',
            'thumbsUpCount','reviewCreatedVersion'])

# %%
disney.info()

# %%
disney.to_csv('C:/Users/USER/Desktop/project/play_diseney.csv')

# %%
# 왓챠
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.frograms.wplay',
    sleep_milliseconds=0,
    lang='ko',
    country='kr',
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
)

# %%
wplay = pd.DataFrame(result)
wplay = wplay.drop(columns=['userImage','replyContent','repliedAt','reviewId',
            'thumbsUpCount','reviewCreatedVersion'])

# %%
wplay.head()

# %%
wplay.info()

# %%
wplay.to_csv('C:/Users/USER/Desktop/project/Play_wplay.csv')

# %%
# 쿠팡
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.coupang.mobile.play',
    sleep_milliseconds=0,
    lang='ko',
    country='kr',
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
)

# %%
coupang = pd.DataFrame(result)
coupang = coupang.drop(columns=['userImage','replyContent','repliedAt','reviewId',
            'thumbsUpCount','reviewCreatedVersion'])

# %%
coupang.info()

# %%
coupang.head()

# %%
coupang.to_csv('C:/Users/USER/Desktop/project/Play_coupang.csv')

# %%
pip install app_store_scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from app_store_scraper import AppStore
import numpy as np
import json

# %%
apnet = AppStore(country='kr',app_name='netflix',app_id='363590051')
apnet.review(how_many=20000)

# %%
apnet.reviews

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
aptnn = pd.DataFrame(np.array(apnet.reviews),columns=['review'])
aptnnn = aptnn.join(pd.DataFrame(aptnn.pop('review').tolist()))

# %%
aptnnn.head()

# %%
aptnnn.info()

# %%
aptnnn.to_csv('/content/drive/MyDrive/newnet.csv')

# %%
# 디즈니
apdi = AppStore(country='kr',app_name='disney',app_id='1446075923')
apdi.review(how_many=20000)
# Out:
# 2022-07-26 08:30:08,825 [INFO] Base - Initialised: AppStore('kr', 'disney', 1446075923)
# 2022-07-26 08:30:08,827 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/kr/app/disney/id1446075923
# 2022-07-26 08:30:27,195 [ERROR] Base - Something went wrong: HTTPSConnectionPool(host='amp-api.apps.apple.com', port=443): Max retries exceeded with url: /v1/catalog/kr/apps/1446075923/reviews?l=en-GB&offset=0&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac (Caused by ResponseError('too many 429 error responses'))
# 2022-07-26 08:30:27,198 [INFO] Base - [id:1446075923] Fetched 0 reviews (0 fetched in total)

# %%
apdi.reviews

# %%
df = pd.DataFrame(np.array(apdi.reviews),columns=['review'])

# %%
df2 = df.join(pd.DataFrame(df.pop('review').tolist()))
df2.head()
# Out:
#    userName  isEdited  rating  \
# 0        악틱     False       5
# 1      이제가을     False       5
# 2    양털끄트머리     False       5
# 3  filco518     False       3
# 4       무무니     False       5
#
#                                               review                date  \
# 0  컨텐츠야 디즈니니까 당연히 넘쳐나는데 검색 기능이 상대적으로 부실합니다. 예를 들면... 2021-11-11 20:33:32
# 1  디즈니 만화와 영화를 사랑하는 사람으로써 몇 가지 개선해주셨으면 하는 바가 있어 남... 2021-11-15 12:15:12
# 2  1년권 끊고 한 달만에 후회했는데 문나이트로 뽕 뽑음.  문나이트만 한 다섯번째 돌... 2022-06-06 05:58:35
# 3  전반 적으로 만족 합니다만 넷플이나 기타 스트리밍 앱에서 되는 것들이 안되는게 있어... 2021-11-14 06:14:34
# 4  성인인증 시 프로필 PIN 넘버 입력 키보드 자판이 안뜨고 구글 크롬캐스트4 사용 ... 2021-11-11 23:59:48
#
#                    title
# 0       좋습니당. 몇 가지 건의 사항
# 1     디즈니를 아끼는 마음으로 남겨요~
# 2           하나만 걸려도 충분하다
# 3  기대하던 디플 앱 드디어 사용 해봤네요
# 4           컨텐츠 많아서 좋긴한데

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1086 entries, 0 to 1085
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   userName  1086 non-null   object
#  1   isEdited  1086 non-null   bool
#  2   rating    1086 non-null   int64
#  3   review    1086 non-null   object
#  4   date      1086 non-null   datetime64[ns]
#  5   title     1086 non-null   object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(3)
# memory usage: 43.6+ KB

# %%
df2.to_csv('C:\Users\nojis\Documents/App_disney.csv')
# Out:
#   File "<ipython-input-71-47d786b1c3d1>", line 1
#     df2.to_csv('C:\Users\nojis\Documents/App_disney.csv')
#               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# 쿠팡
apcou = AppStore(country='kr',app_name='coupangplay',app_id='1536885649')
apcou.review(how_many=20000)
# Out:
# 2022-07-26 08:27:20,568 [INFO] Base - Initialised: AppStore('kr', 'coupangplay', 1536885649)
# 2022-07-26 08:27:20,571 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/kr/app/coupangplay/id1536885649
# 2022-07-26 08:27:43,078 [ERROR] Base - Something went wrong: HTTPSConnectionPool(host='amp-api.apps.apple.com', port=443): Max retries exceeded with url: /v1/catalog/kr/apps/1536885649/reviews?l=en-GB&offset=280&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac (Caused by ResponseError('too many 429 error responses'))
# 2022-07-26 08:27:43,082 [INFO] Base - [id:1536885649] Fetched 280 reviews (280 fetched in total)

# %%
apcou.reviews
# Out:
# [{'date': datetime.datetime(2022, 4, 5, 23, 14, 20),
#   'developerResponse': {'body': '안녕하세요 bhe808 고객님, 쿠팡플레이입니다 :) 쿠팡플레이를 이용해주시고 따뜻한 리뷰 남겨주셔서 감사합니다. 앞으로도 더 편리한 서비스와 다양한 콘텐츠를 제공 드릴 수 있도록 더욱 노력하겠습니다. 최고의 OTT 서비스가 될 쿠팡플레이를 기대해주시고 계속해서 함께 해주세요! 💙 감사합니다.',
#    'id': 29022389,
#    'modified': '2022-04-07T04:34:43Z'},
#   'isEdited': False,
#   'rating': 5,
#   'review': '와우회원인지 몇개월 됬는데 이런 콘텐츠가 있는줄 몰랐네요~와~해리포터가 ?????리얼???아들이 계속 돈내고 시즌전부를 돌려봐서 좀 부담됬는데...아침 이거를 발견하고 진짜 넘 좋았어요😃이제 영문자막으로 공부도 할겸^^실컷 보게 해야겠어요~딸이 보더니 공부에 관련된 영상도 있다고^^자기가 찾던 영화도 있다고^^그리고 좋은 작품들을 복잡한 절차없이 다운받아서(아직 다운해서 보지는 못했음^^)정말 잘 이용할것같아요~이런 혜택을 왜 못누렸는지😅이제라도 알게되서 넘 좋네요^^',
#   'title': '최고',
#   'userName': 'bhe808'},
#  {'date': datetime.datetime(2022, 4, 30, 7, 49, 46),
# ...

# %%
df = pd.DataFrame(np.array(apcou.reviews),columns=['review'])
df2 = df.join(pd.DataFrame(df.pop('review').tolist()))
df2.head()
# Out:
#                  date                                             review  \
# 0 2022-04-05 23:14:20  와우회원인지 몇개월 됬는데 이런 콘텐츠가 있는줄 몰랐네요~와~해리포터가 ?????리...
# 1 2022-04-30 07:49:46  초반엔 사실 컨텐츠 부족으로 있으나 마나 였고 차치 배달 때문에 해둔거라 방치 해뒀...
# 2 2021-12-05 15:50:10  쿠팡을 갓팡이라 하는 이유 중 하나가 바로 쿠팡플레이일 정도로 감동받으며 서비스를 ...
# 3 2021-11-20 11:22:18  쿠팡와우 몇년 사용중인데 이거 있다는거 오늘 알았음. ㅋㅋㅋㅋㅋㅋㅋ 정말 깊은 빡침...
# 4 2021-11-26 15:21:02  2,900원에 있는 없는 거 다 퍼주시네.. 국민 배송앱이라고 말해도 과언이 아닐 ...
#
#      userName  rating                              title  \
# 0      bhe808       5                                 최고
# 1      악플만 적음       5                              진짜 최고
# 2   Chadiiiii       5             애플TV용 앱개발 좀 서둘러 부탁드려요.
# 3       넷플사용자       5  한달 배송포함 2900원에 이정도면 진짜 절.대 나쁜거 아님
# 4  Jsy lovely       5               쿠팡 이렇게 장사하면 남는게 뭐예요?
#
#                                    developerResponse  isEdited
# 0  {'id': 29022389, 'body': '안녕하세요 bhe808 고객님, 쿠팡...     False
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               280 non-null    datetime64[ns]
#  1   review             280 non-null    object
#  2   userName           280 non-null    object
#  3   rating             280 non-null    int64
#  4   title              280 non-null    object
#  5   developerResponse  276 non-null    object
#  6   isEdited           280 non-null    bool
# dtypes: bool(1), datetime64[ns](1), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df2.to_csv('/content/drive/MyDrive/newcou.csv')
