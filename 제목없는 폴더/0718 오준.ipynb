# %%
import pandas as pd

# %%
apd = pd.read_csv('C:/Users/USER/Desktop/project/App_disney.csv')

# %%
apn = pd.read_csv('C:/Users/USER/Desktop/project/App_netflix.csv')

# %%
apw = pd.read_csv('C:/Users/USER/Desktop/project/App_watcha.csv')

# %%
pdi = pd.read_csv('C:/Users/USER/Desktop/project/play_diseney.csv')

# %%
pn = pd.read_csv('C:/Users/USER/Desktop/project/play_netflix.csv')

# %%
pw = pd.read_csv('C:/Users/USER/Desktop/project/play_wPlay.csv')

# %%
pc = pd.read_csv('C:/Users/USER/Desktop/project/play_coupang.csv')

# %%
apd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1078 entries, 0 to 1077
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1078 non-null   int64
#  1   rating      1078 non-null   int64
#  2   review      1078 non-null   object
#  3   date        1078 non-null   object
#  4   userName    1078 non-null   object
#  5   isEdited    1078 non-null   bool
#  6   title       1078 non-null   object
# dtypes: bool(1), int64(2), object(4)
# memory usage: 51.7+ KB

# %%
apd = apd.drop(columns=['Unnamed: 0','isEdited'])

# %%
apd.head()
# Out:
#    rating                                             review  \
# 0       5  컨텐츠야 디즈니니까 당연히 넘쳐나는데 검색 기능이 상대적으로 부실합니다. 예를 들면...
# 1       5  디즈니 만화와 영화를 사랑하는 사람으로써 몇 가지 개선해주셨으면 하는 바가 있어 남...
# 2       5  1년권 끊고 한 달만에 후회했는데 문나이트로 뽕 뽑음.  문나이트만 한 다섯번째 돌...
# 3       3  전반 적으로 만족 합니다만 넷플이나 기타 스트리밍 앱에서 되는 것들이 안되는게 있어...
# 4       5  성인인증 시 프로필 PIN 넘버 입력 키보드 자판이 안뜨고 구글 크롬캐스트4 사용 ...
#
#                   date  userName                  title
# 0  2021-11-11 20:33:32        악틱       좋습니당. 몇 가지 건의 사항
# 1  2021-11-15 12:15:12      이제가을     디즈니를 아끼는 마음으로 남겨요~
# 2  2022-06-06 05:58:35    양털끄트머리           하나만 걸려도 충분하다
# 3  2021-11-14 06:14:34  filco518  기대하던 디플 앱 드디어 사용 해봤네요
# 4  2021-11-11 23:59:48       무무니           컨텐츠 많아서 좋긴한데

# %%
pdi.columns = ['userName','review','rating','date']
pdi
# Out:
#        userName                                             review  rating  \
# 0          bo B  콘텐츠를 떠나서 앱 개선이 시급해 보입니다. 앱 개발자 본인들은 평소 스트리밍 이용...       1
# 1       얄리얄리얄라서  밝기 조절 없음, 음량 조절 없음, 팝업 재생 없음, 재생 속도 조절 없음, 재생중...       1
# 2        lal la  화면 밝기 조절 기능 없고, 앱 자체 팝업모드 기능 안드로이드만 미지원이라 갤럭시 ...       5
# 3         sun s  불편한부분 정말 너무 많지만 하나만 얘기할게요 대체 왜 다음회차 자동으로 넘어가는 ...       1
# 4            헐헐  영화보는컨텐츠이기 때문에 영화에 관한건 비슷하리라 보는데...최소한의 플레이 옵션을...       1
# ...         ...                                                ...     ...
# 3457        김지혜                                                  짱       5
# 3458        정윤재                                                  👍       5
# 3459  Jacob Won                                   Good 😉😉😉😉😉😉😉😉😉😉😉       1
# 3460        황은비  1000000000000000000000000000000000000000000000...       1
# 3461       배배민환                                          👍👍👍👍👍👍👍👍👍       5
#
#                      date
# 0     2022-06-17 23:07:38
# ...

# %%
dis = pd.concat([apd,pdi])
dis
# Out:
#       rating                                             review  \
# 0          5  컨텐츠야 디즈니니까 당연히 넘쳐나는데 검색 기능이 상대적으로 부실합니다. 예를 들면...
# 1          5  디즈니 만화와 영화를 사랑하는 사람으로써 몇 가지 개선해주셨으면 하는 바가 있어 남...
# 2          5  1년권 끊고 한 달만에 후회했는데 문나이트로 뽕 뽑음.  문나이트만 한 다섯번째 돌...
# 3          3  전반 적으로 만족 합니다만 넷플이나 기타 스트리밍 앱에서 되는 것들이 안되는게 있어...
# 4          5  성인인증 시 프로필 PIN 넘버 입력 키보드 자판이 안뜨고 구글 크롬캐스트4 사용 ...
# ...      ...                                                ...
# 3457       5                                                  짱
# 3458       5                                                  👍
# 3459       1                                   Good 😉😉😉😉😉😉😉😉😉😉😉
# 3460       1  1000000000000000000000000000000000000000000000...
# 3461       5                                          👍👍👍👍👍👍👍👍👍
#
#                      date   userName                  title
# 0     2021-11-11 20:33:32         악틱       좋습니당. 몇 가지 건의 사항
# 1     2021-11-15 12:15:12       이제가을     디즈니를 아끼는 마음으로 남겨요~
# ...

# %%
dis.to_csv('C:/Users/USER/Desktop/project/disney.csv')

# %%
apd.rating.value_counts()
# Out:
# 5    394
# 1    299
# 3    164
# 4    143
# 2     78
# Name: rating, dtype: int64

# %%
apn.rating.value_counts()
# Out:
# 5    792
# 4    741
# 3    702
# 1    525
# 2    300
# Name: rating, dtype: int64

# %%
apw.rating.value_counts()
# Out:
# 5    1172
# 4     378
# 1     222
# 3     166
# 2      62
# Name: rating, dtype: int64

# %%
pdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3462 entries, 0 to 3461
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3462 non-null   int64
#  1   userName    3462 non-null   object
#  2   content     3462 non-null   object
#  3   score       3462 non-null   int64
#  4   at          3462 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 135.4+ KB

# %%
pdi.score.value_counts()
# Out:
# 1    1588
# 5     844
# 3     417
# 2     332
# 4     281
# Name: score, dtype: int64

# %%
pn.score.value_counts()
# Out:
# 1    9239
# 5    7240
# 3    2637
# 4    2546
# 2    1770
# Name: score, dtype: int64

# %%
pw.score.value_counts()
# Out:
# 5    9042
# 1    4534
# 4    3336
# 3    2171
# 2    1222
# Name: score, dtype: int64

# %%
apn = apn.drop(columns= ['Unnamed: 0','isEdited'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11976/1836231222.py in <module>
# ----> 1 apn = apn.drop(columns= ['Unnamed: 0','isEdited'])
#       2 apn.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
apn.head()
# Out:
#      userName                     title  \
# 0   mugmuggle       업데이후 이후로 자막이 혼자 꺼져요
# 1       Jdhhc              모자이크 처리 좀 제발
# 2         양세찬  그냥 개발적으로 개선됐으면 하는 부분 적어요
# 3         와아나    별점 높게 하면 위로 뜬다길래 높게 함.
# 4  친구할인코드 묵찌빠       좋아요한 작품만 따로 볼 수 있게…
#
#                                               review                 date  \
# 0  보고있는데 자막이 자꾸 혼자 꺼져요\n영어면 또 그냥 듣다가 키겠는데 다른언어면 다...  2020-09-29 18:36:48
# 1  방송 규제 때문에 모자이크 처리하는 건 알겠지만 왜 애니메이션만 그런 규제를 걸어놓...  2021-11-11 04:52:14
# 2  어플 자체는 완전 잘 쓰고 있습니다. 다만\n1. 어떤 작품을 실수로 눌러 재생했을...  2019-12-12 08:36:39
# 3  일단 먼저 영화가 너무 적음;; 넷플릭스 가격은 겁나 비싸졌는데 영화는 왤케 빠져요...  2022-01-16 16:50:05
# 4  다른거는 다 좋은데 찜한 목록 말고 자신이 평가한 목록들 볼 수 있었으면 좋겠어요....  2022-01-10 11:35:07
#
#    rating
# 0       3
# 1       5
# 2       5
# 3       5
# 4       5

# %%
pn= pn.drop(columns='Unnamed: 0')

# %%
pn.columns=['userName','review','rating','date']
pn.head()
# Out:
#   userName                                             review  rating  \
# 0  vgn0509  미드, 영화 보면서 영어공부용으로 잘 사용하고 있습니다. 다만, 모바일에서 뒤로가기...       4
# 1      윤서영  전체적으로 잘 보고있긴하지만 불편한 점이 있어 건의드립니다. 멤버쉽 해지하고나서 나...       3
# 2   nhi 03  요즘 보고 싶은 콘텐츠,흥미로운 콘텐츠가 여럿 들어와서 정말 좋습니다! 그런데 혹시...       5
# 3       가뷰  불편한 점이 소비자 입장에서는 눈에 띄일 수 밖에 없죠. 첫번째, 번역이 정확하지 ...       3
# 4     샤인시티  넷플릭스 1년 가까이 이용중인데 타사 플랫폼보다 컨텐츠도 많고 여러기능들이 있어 저...       5
#
#                   date
# 0  2022-06-21 09:31:49
# 1  2022-06-26 14:56:13
# 2  2022-06-12 21:00:08
# 3  2022-06-04 17:56:41
# 4  2022-05-26 13:34:19

# %%
netflix = pd.concat([apn,pn])

# %%
netflix = netflix.drop(columns='title')

# %%
netflix.to_csv('C:/Users/USER/Desktop/project/netflix.csv')

# %%
netflix = pd.read_csv('C:/Users/USER/Desktop/project/netflix.csv')

# %%
netflix = netflix.dropna()

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26490 entries, 0 to 26491
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26490 non-null  int64
#  1   userName    26490 non-null  object
#  2   review      26490 non-null  object
#  3   date        26490 non-null  object
#  4   rating      26490 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 1.2+ MB

# %%
import pandas as pd
import numpy as np
import konlpy
from sklearn.feature_extraction.text import CountVectorizer   # tf-idf 방식을 사용하려면 대신 TfidfVectorizer를 import
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import platform
print(platform.architecture())
# Out:
# ('64bit', 'WindowsPE')

# %%
# comment에 내용이 없는 행 파악
print(len(netflix[netflix['review'] == '']))
# Out:
# 0

# %%
import re

# %%
# 텍스트를 tokenize해서 adjective, verb, noun만 추출하는 함수

def tokenize_korean_text(text): 
  text_filtered = re.sub('[^,.?!\w\s]','', text)  # 기호 앲애기

  okt = konlpy.tag.Okt() 
  Okt_morphs = okt.pos(text_filtered)  # 텍스트 추출

  words = []
  for word, pos in Okt_morphs:
    if pos == 'Adjective' or pos == 'Verb' or pos == 'Noun': 
      words.append(word)

  words_str = ' '.join(words)
  return words_str

# %%
X_texts = []
y = []

for star, comment in zip(netflix['rating'], netflix['review']):
  tokenized_comment = tokenize_korean_text(comment)  # 위에서 만들었던 함수로 comment 쪼개기
  X_texts.append(tokenized_comment)

  y.append(1 if star > 3 else -1)

print(f'원래 text 수: {len(netflix)}')
print(f'text 수: {len(X_texts)}')    
print(X_texts[:5])
# Out:
# 원래 text 수: 26490
# text 수: 26490
# ['보고있는데 자막 자꾸 혼자 꺼져요 영어 또 그냥 듣다가 키 겠는데 다른언어 다시 껏 켰다 다시 돌아가서 보고 해야되 서 배 빡침 개선 해주세요 넷플 진짜 추가 됬으면 하는건 내 작품 보기 전부 아니어도 제 좋다고 표시 작품 앱 다시 볼수있었으면 좋겠어요', '방송 규제 때문 모자이크 처리 하는 건 알겠지만 왜 애니메이션 그런 규제 걸어놓았는지 모르겠습니다 그것 다른 나라 그렇지 않은데 우리나라 그런 규제 있다고 합니다 이 때문 영상 볼 때 몰입도 현저 떨어져요 타 서비스 웨 왓 무 삭제 심의 버전 받아 온다고 하는데 왜 넷플릭스 방송 용 심의 버전 가지 오는지 모르겠습니다 평소 넷플릭스 정말 애용 하는데 이 부분 고쳐주시면 정말 감사하겠습니다 부탁드리겠습니다', '어플 자체 완전 잘 쓰고 있습니다 다만 어떤 작품 실수 눌러 재생 했을 때 해당 작품 계속 시청 중인 콘텐츠 뜨는데 걸 삭제 할 수 있었으면 좋겠어요 아이폰 사용 중 입니다 재생 종료 후 메인 화면 정상 출력 되지 않고 상단 중앙 부 확대 되어 출력 되는 경우 있습니다 한 화 본 후 바로 터치 해 하단 있는 다음 눌러 넘어갈 시 다음 화가 재생 되고 있음에도 한 화 마지막 부분 자동 팝업 되는 다음 화 인터페이스 계속 떠 있습니다 터치 해도 안 사라져요 고생 많으십니다', '일단 먼저 영화 적음 넷플릭스 가격 겁나 비싸졌는데 영화 왤케 빠져요 장난 하세요 영화 장르 많은데 중 있는게 거의 없잖아요 드라마 모르겠는데 영화 넣어주던가요 그럴거면 가격 내리세요 처음 괜찮다가 왜 변하는거지 이해 할수가 없네 됐고 가격 내릴거면 영화 더 넣으세요 자막 크게 직접 수정 할수 있게 좀 만들어주 셈 진짜 오', '거 좋은데 찜 목록 자신 평가 목록 볼 수 있었으면 좋겠어요 예전 재밌게 봤던것 들 정 주행 자주 하는 편 좋다고 평가 것 못 봤서 좀 아쉽네요 평가 목록 꼭 추가 됐으면 좋겠어요']

# %%
# train_test_split
X_train_texts, X_test_texts, y_train, y_test = train_test_split(X_texts, y, test_size=0.2, random_state=0)

# %%
# CountVectorizer로 vector화
tf_vectorizer = CountVectorizer(min_df=1, ngram_range=(1,1))
X_train_tf = tf_vectorizer.fit_transform(X_train_texts)  # training data에 맞게 fit & training data를 transform
X_test_tf = tf_vectorizer.transform(X_test_texts) # test data를 transform

vocablist = [word for word, number in sorted(tf_vectorizer.vocabulary_.items(), key=lambda x:x[1])]  # 단어들을 번호 기준 내림차순으로 저장

# %%
print(X_train_tf[:1], '\n')
print(X_test_tf[:1], '\n')
print(vocablist[:3])
# Out:
#   (0, 14201)	1
#   (0, 18101)	1
#   (0, 7444)	1
#   (0, 973)	1
#   (0, 10113)	1
#
#   (0, 621)	1
#   (0, 1191)	1
#   (0, 1979)	1
#   (0, 2424)	1
#   (0, 2564)	1
#   (0, 4928)	1
#   (0, 6795)	1
#   (0, 9068)	1
#   (0, 9418)	1
#   (0, 10128)	1
#   (0, 10148)	1
#   (0, 16004)	2
#   (0, 16031)	1
#   (0, 16518)	1
#   (0, 16614)	1
#   (0, 18980)	1
#   (0, 19323)	1
#   (0, 19562)	1
#   (0, 22749)	1
#
# ['가거나', '가게', '가게끔']

# %%
model = LogisticRegression(C=0.1, penalty='l2', random_state=0)
model.fit(X_train_tf, y_train)  # 학습
# Out:
# LogisticRegression(C=0.1, random_state=0)

# %%
LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
                   intercept_scaling=1, l1_ratio=None, max_iter=100,
                   multi_class='auto', n_jobs=None, penalty='l2',
                   random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
                   warm_start=False)
# Out:
# LogisticRegression(C=0.1, random_state=0)

# %%
y_test_pred = model.predict(X_test_tf)

print('Misclassified samples: {} out of {}'.format((y_test_pred != y_test).sum(), len(y_test)))
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, y_test_pred)))  # model.score(X_test_tf, y_test)로 계산해도 됨
# Out:
# Misclassified samples: 980 out of 5298
# Accuracy: 0.82

# %%
coefficients = model.coef_.tolist()

sorted_coefficients = sorted(enumerate(coefficients[0]), key=lambda x:x[1], reverse=True)
# coefficients(계수)가 큰 값부터 내림차순으로 정렬

print('긍정적인 단어 Top 10 (높은 평점과 상관관계가 강한 단어들)')
for word_num, coef in sorted_coefficients[:10]:
  print('{0:}({1:.3f})'.format(vocablist[word_num], coef))

print('\n부정적인 단어 Top 10 (낮은 평점과 상관관계가 강한 단어들)')
for word_num, coef in sorted_coefficients[-10:]: 
  print('{0:}({1:.3f})'.format(vocablist[word_num], coef))
# Out:
# 긍정적인 단어 Top 10 (높은 평점과 상관관계가 강한 단어들)
# 좋아요(2.309)
# 최고(1.627)
# 좋음(1.465)
# 좋습니다(1.346)
# 좋네요(0.985)
# 조아요(0.977)
# 좋다(0.950)
# 감사합니다(0.926)
# 재밌어요(0.911)
# 좋아용(0.891)
#
# 부정적인 단어 Top 10 (낮은 평점과 상관관계가 강한 단어들)
# 플립(-0.931)
# 최악(-0.964)
# 들어가져요(-0.973)
# 자꾸(-0.988)
# 쓰레기(-1.000)
# 오류(-1.082)
# 아니(-1.129)
# 안됨(-1.234)
# 접속(-1.237)
# 나옴(-1.240)

# %%
# 긍정/부정 테스트용 함수 생성
def guess_good_or_bad(text):
  text_filtered = text.replace('.', '').replace(',','').replace("'","").replace('·', ' ').replace('=','') 

  okt = konlpy.tag.Okt() 
  Okt_morphs = okt.pos(text_filtered) 

  words = []
  for word, pos in Okt_morphs:
    if pos == 'Adjective' or pos == 'Verb' or pos == 'Noun':
      words.append(word)
  words_str = ' '.join(words)
  
  new_text_tf = tf_vectorizer.transform([words_str])

  if model.predict(new_text_tf) == 1:
    print('긍정')
  else:
    print('부정')

# %%
netflix.head()
# Out:
#    Unnamed: 0    userName                                             review  \
# 0           0   mugmuggle  보고있는데 자막이 자꾸 혼자 꺼져요\n영어면 또 그냥 듣다가 키겠는데 다른언어면 다...
# 1           1       Jdhhc  방송 규제 때문에 모자이크 처리하는 건 알겠지만 왜 애니메이션만 그런 규제를 걸어놓...
# 2           2         양세찬  어플 자체는 완전 잘 쓰고 있습니다. 다만\n1. 어떤 작품을 실수로 눌러 재생했을...
# 3           3         와아나  일단 먼저 영화가 너무 적음;; 넷플릭스 가격은 겁나 비싸졌는데 영화는 왤케 빠져요...
# 4           4  친구할인코드 묵찌빠  다른거는 다 좋은데 찜한 목록 말고 자신이 평가한 목록들 볼 수 있었으면 좋겠어요....
#
#                   date  rating
# 0  2020-09-29 18:36:48       3
# 1  2021-11-11 04:52:14       5
# 2  2019-12-12 08:36:39       5
# 3  2022-01-16 16:50:05       5
# 4  2022-01-10 11:35:07       5

# %%
netflix.loc[netflix['rating'] == 1]
# Out:
#        Unnamed: 0      userName  \
# 15             15     SandWave9
# 21             21         후레후레이
# 23             23         오리나마나
# 39             39         hjGIL
# 44             44          심슨매냐
# ...           ...           ...
# 26428       23368      Its Me??
# 26431       23371  Star_Lee DAD
# 26433       23373           송치완
# 26454       23394           오애영
# 26482       23422    Google 사용자
#
#                                                   review                 date  \
# 15     프로필 2개를 사용중인데 한 프로필에서 홈화면에 아무 것도 뜨지 않는 문제가 자주 ...  2022-01-06 05:23:53
# 21     한국은 24시간 고객센터 지원이 안되서 아침까지 기다려야 하네요.\n이메일 주소와 ...  2020-02-10 15:54:15
# 23     한번도 안썼는데 돈만 계속 빨아먹고있었음. 아니 한번도 이용안했으면 전화상으로 결제...  2022-05-17 00:23:49
# 39     추천영상좀 자제해주세요\n인종차별을 할려는건 아니지만 젖이랑 배 내놓은 무슨 살색의...  2019-08-13 03:42:31
# 44     마지막 재생시간 3-4분 가량 남았을때 그냥 검은화면만 나옴..업뎃하고 이상해짐.....  2021-09-18 14:08:27
# ...                                                  ...                  ...
# ...

# %%
X_texts[1:3] # --> 5점 리뷰
# Out:
# ['방송 규제 때문 모자이크 처리 하는 건 알겠지만 왜 애니메이션 그런 규제 걸어놓았는지 모르겠습니다 그것 다른 나라 그렇지 않은데 우리나라 그런 규제 있다고 합니다 이 때문 영상 볼 때 몰입도 현저 떨어져요 타 서비스 웨 왓 무 삭제 심의 버전 받아 온다고 하는데 왜 넷플릭스 방송 용 심의 버전 가지 오는지 모르겠습니다 평소 넷플릭스 정말 애용 하는데 이 부분 고쳐주시면 정말 감사하겠습니다 부탁드리겠습니다',
#  '어플 자체 완전 잘 쓰고 있습니다 다만 어떤 작품 실수 눌러 재생 했을 때 해당 작품 계속 시청 중인 콘텐츠 뜨는데 걸 삭제 할 수 있었으면 좋겠어요 아이폰 사용 중 입니다 재생 종료 후 메인 화면 정상 출력 되지 않고 상단 중앙 부 확대 되어 출력 되는 경우 있습니다 한 화 본 후 바로 터치 해 하단 있는 다음 눌러 넘어갈 시 다음 화가 재생 되고 있음에도 한 화 마지막 부분 자동 팝업 되는 다음 화 인터페이스 계속 떠 있습니다 터치 해도 안 사라져요 고생 많으십니다']

# %%
guess_good_or_bad('방송 규제 때문 모자이크 처리 하는 건 알겠지만 왜 애니메이션 그런 규제 걸어놓았는지 모르겠습니다 그것 다른 나라 그렇지 않은데 우리나라 그런 규제 있다고 합니다 이 때문 영상 볼 때 몰입도 현저 떨어져요 타 서비스 웨 왓 무 삭제 심의 버전 받아 온다고 하는데 왜 넷플릭스 방송 용 심의 버전 가지 오는지 모르겠습니다 평소 넷플릭스 정말 애용 하는데 이 부분 고쳐주시면 정말 감사하겠습니다 부탁드리겠습니다')
# Out:
# 긍정

# %%
X_texts[15:16] # --> 1점 리뷰
# Out:
# ['프로필 개 사용 한 프로필 홈 화면 아무 것 뜨지 않는 문제 자주 발생 합니다 접속 할 수 없습니다 위 메세지 동일 아이폰 한 프로필 빈번 하게 나타납니다 말 부터 해당 증상 나타나며 윈도우 앱 등 제대로 작동 합니다']

# %%
guess_good_or_bad('프로필 개 사용 한 프로필 홈 화면 아무 것 뜨지 않는 문제 자주 발생 합니다 접속 할 수 없습니다 위 메세지 동일 아이폰 한 프로필 빈번 하게 나타납니다 말 부터 해당 증상 나타나며 윈도우 앱 등 제대로 작동 합니다')
# Out:
# 부정
