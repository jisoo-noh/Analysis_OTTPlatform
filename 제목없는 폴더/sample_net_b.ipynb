# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/net/net_2019_1q.csv')
df.score.mean()
# Out:
# 2.688336520076482

# %%
df = pd.read_csv('/content/drive/MyDrive/net/net_2019_2q.csv')
df.score.mean()
# Out:
# 2.8306451612903225

# %%
df = pd.read_csv('/content/drive/MyDrive/net/net_2019_3q.csv')
df.score.mean()
# Out:
# 2.867283950617284

# %%
df = pd.read_csv('/content/drive/MyDrive/net/net_2019_4q.csv')
df.score.mean()
# Out:
# 2.7823204419889502

# %%
df = pd.read_csv('/content/drive/MyDrive/net/net_2020_1q.csv')
df.score.mean()
# Out:
# 3.024045261669024

# %%
df = pd.read_csv('/content/drive/MyDrive/net/net_2020_2q.csv')
df.score.mean()
# Out:
# 2.6978967495219885

# %%
df = pd.read_csv('/content/drive/MyDrive/net/net_2020_3q.csv')
df.score.mean()
# Out:
# 2.7600182149362475

# %%
df = pd.read_csv('/content/drive/MyDrive/net/net_2020_4q.csv')
df.score.mean()
# Out:
# 3.277163305139883

# %%
df = pd.read_csv('/content/drive/MyDrive/net/net_2021_1q.csv')
df.score.mean()
# Out:
# 3.2822299651567945

# %%
df = pd.read_csv('/content/drive/MyDrive/net/net_2021_2q.csv')
df.score.mean()
# Out:
# 2.438483547925608

# %%
df = pd.read_csv('/content/drive/MyDrive/net/net_2021_3q.csv')
df.score.mean()
# Out:
# 2.738031914893617

# %%
df = pd.read_csv('/content/drive/MyDrive/net/net_2021_4q.csv')
df.score.mean()
# Out:
# 2.9663608562691133

# %%
df = pd.read_csv('/content/drive/MyDrive/net/net_2022_1q.csv')
df.score.mean()
# Out:
# 2.9907834101382487

# %%
df = pd.read_csv('/content/drive/MyDrive/net/net_2022_2q.csv')
df.score.mean()
# Out:
# 3.4075829383886256

# %%
# 각 쿼터의 score 평균
b = [2.688336520076482, 2.8306451612903225, 2.867283950617284, 2.7823204419889502, 
     3.024045261669024, 2.6978967495219885, 2.7600182149362475, 3.277163305139883,
     3.2822299651567945, 2.438483547925608, 2.438483547925608, 2.9663608562691133,
     2.9907834101382487, 3.4075829383886256]

# %%
# 각 쿼터의 score 평균
b = [2.688, 2.831, 2.867, 2.782, 
     3.024, 2.698, 2.760, 3.277,
     3.282, 2.438, 2.438, 2.966,
     2.991, 3.408]
