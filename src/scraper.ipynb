# %%
import pandas as pd

# %%
pip install app_store_scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting app_store_scraper
#   Downloading app_store_scraper-0.3.5-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: requests==2.23.0 in /usr/local/lib/python3.7/dist-packages (from app_store_scraper) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests==2.23.0->app_store_scraper) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests==2.23.0->app_store_scraper) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests==2.23.0->app_store_scraper) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests==2.23.0->app_store_scraper) (2.10)
# Installing collected packages: app-store-scraper
# Successfully installed app-store-scraper-0.3.5

# %%
from app_store_scraper import AppStore
import numpy as np
import json

# %%
apnet = AppStore(country='kr',app_name='netflix',app_id='363590051')
apnet.review(how_many=20000)
# Out:
# 2022-07-20 19:13:39,402 [INFO] Base - Initialised: AppStore('kr', 'netflix', 363590051)
# 2022-07-20 19:13:39,404 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/kr/app/netflix/id363590051
# 2022-07-20 19:13:44,580 [INFO] Base - [id:363590051] Fetched 480 reviews (480 fetched in total)
# 2022-07-20 19:13:49,849 [INFO] Base - [id:363590051] Fetched 960 reviews (960 fetched in total)
# 2022-07-20 19:13:55,192 [INFO] Base - [id:363590051] Fetched 1460 reviews (1460 fetched in total)
# 2022-07-20 19:14:00,646 [INFO] Base - [id:363590051] Fetched 1940 reviews (1940 fetched in total)
# 2022-07-20 19:14:20,551 [ERROR] Base - Something went wrong: HTTPSConnectionPool(host='amp-api.apps.apple.com', port=443): Max retries exceeded with url: /v1/catalog/kr/apps/363590051/reviews?l=en-GB&offset=2000&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac (Caused by ResponseError('too many 429 error responses'))
# 2022-07-20 19:14:20,554 [INFO] Base - [id:363590051] Fetched 2000 reviews (2000 fetched in total)

# %%
apnet.reviews

# %%
aptnn = pd.DataFrame(np.array(apnet.reviews),columns=['review'])
aptnnn = aptnn.join(pd.DataFrame(aptnn.pop('review').tolist()))

# %%
aptnnn.head()
# Out:
#                  date  rating  isEdited    userName  \
# 0 2020-09-29 18:36:48       3     False   mugmuggle
# 1 2021-11-11 04:52:14       5     False       Jdhhc
# 2 2019-12-12 08:36:39       5     False         양세찬
# 3 2022-01-16 16:50:05       5     False         와아나
# 4 2022-01-10 11:35:07       5     False  친구할인코드 묵찌빠
#
#                                               review                     title
# 0  보고있는데 자막이 자꾸 혼자 꺼져요\n영어면 또 그냥 듣다가 키겠는데 다른언어면 다...       업데이후 이후로 자막이 혼자 꺼져요
# 1  방송 규제 때문에 모자이크 처리하는 건 알겠지만 왜 애니메이션만 그런 규제를 걸어놓...              모자이크 처리 좀 제발
# 2  어플 자체는 완전 잘 쓰고 있습니다. 다만\n1. 어떤 작품을 실수로 눌러 재생했을...  그냥 개발적으로 개선됐으면 하는 부분 적어요
# 3  일단 먼저 영화가 너무 적음;; 넷플릭스 가격은 겁나 비싸졌는데 영화는 왤케 빠져요...    별점 높게 하면 위로 뜬다길래 높게 함.
# 4  다른거는 다 좋은데 찜한 목록 말고 자신이 평가한 목록들 볼 수 있었으면 좋겠어요....       좋아요한 작품만 따로 볼 수 있게…

# %%
aptnnn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      2000 non-null   datetime64[ns]
#  1   rating    2000 non-null   int64
#  2   isEdited  2000 non-null   bool
#  3   userName  2000 non-null   object
#  4   review    2000 non-null   object
#  5   title     2000 non-null   object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(3)
# memory usage: 80.2+ KB

# %%
aptnnn.to_csv('C:\\Users\\nojis\\Desktop\\aptnnn.csv')

# %%
# 디즈니
apdi = AppStore(country='kr',app_name='disney',app_id='1446075923')
apdi.review(how_many=20000)
# Out:
# 2022-07-20 19:27:47,669 [INFO] Base - Initialised: AppStore('kr', 'disney', 1446075923)
# 2022-07-20 19:27:47,672 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/kr/app/disney/id1446075923
# 2022-07-20 19:28:07,749 [ERROR] Base - Something went wrong: HTTPSConnectionPool(host='amp-api.apps.apple.com', port=443): Max retries exceeded with url: /v1/catalog/kr/apps/1446075923/reviews?l=en-GB&offset=100&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac (Caused by ResponseError('too many 429 error responses'))
# 2022-07-20 19:28:07,752 [INFO] Base - [id:1446075923] Fetched 100 reviews (100 fetched in total)

# %%
apdi.reviews

# %%
df = pd.DataFrame(np.array(apdi.reviews),columns=['review'])

# %%
df2 = df.join(pd.DataFrame(df.pop('review').tolist()))
df2.head()
# Out:
#                  date  isEdited  userName  rating                  title  \
# 0 2021-11-11 20:33:32     False        악틱       5       좋습니당. 몇 가지 건의 사항
# 1 2021-11-15 12:15:12     False      이제가을       5     디즈니를 아끼는 마음으로 남겨요~
# 2 2022-06-06 05:58:35     False    양털끄트머리       5           하나만 걸려도 충분하다
# 3 2021-11-14 06:14:34     False  filco518       3  기대하던 디플 앱 드디어 사용 해봤네요
# 4 2021-11-11 23:59:48     False       무무니       5           컨텐츠 많아서 좋긴한데
#
#                                               review
# 0  컨텐츠야 디즈니니까 당연히 넘쳐나는데 검색 기능이 상대적으로 부실합니다. 예를 들면...
# 1  디즈니 만화와 영화를 사랑하는 사람으로써 몇 가지 개선해주셨으면 하는 바가 있어 남...
# 2  1년권 끊고 한 달만에 후회했는데 문나이트로 뽕 뽑음.  문나이트만 한 다섯번째 돌...
# 3  전반 적으로 만족 합니다만 넷플이나 기타 스트리밍 앱에서 되는 것들이 안되는게 있어...
# 4  성인인증 시 프로필 PIN 넘버 입력 키보드 자판이 안뜨고 구글 크롬캐스트4 사용 ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      100 non-null    datetime64[ns]
#  1   isEdited  100 non-null    bool
#  2   userName  100 non-null    object
#  3   rating    100 non-null    int64
#  4   title     100 non-null    object
#  5   review    100 non-null    object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(3)
# memory usage: 4.1+ KB

# %%
df2.to_csv('C:\\Users\\nojis\\Desktop\\apdi.csv')

# %%
# 쿠팡
apcou = AppStore(country='kr',app_name='coupangplay',app_id='1536885649')
apcou.review(how_many=20000)
# Out:
# 2022-07-20 19:40:13,220 [INFO] Base - Initialised: AppStore('kr', 'coupangplay', 1536885649)
# 2022-07-20 19:40:13,225 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/kr/app/coupangplay/id1536885649
# 2022-07-20 19:40:33,616 [ERROR] Base - Something went wrong: HTTPSConnectionPool(host='amp-api.apps.apple.com', port=443): Max retries exceeded with url: /v1/catalog/kr/apps/1536885649/reviews?l=en-GB&offset=220&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac (Caused by ResponseError('too many 429 error responses'))
# 2022-07-20 19:40:33,619 [INFO] Base - [id:1536885649] Fetched 220 reviews (220 fetched in total)

# %%
apcou.reviews

# %%
df = pd.DataFrame(np.array(apcou.reviews),columns=['review'])

# %%
df2 = df.join(pd.DataFrame(df.pop('review').tolist()))
df2.head()
# Out:
#                                               review  rating  \
# 0  10년전 첫째 낳기전 뱀다를 시즌5까지인가 봤었는데 임신하면서 태교땜에 참고 그만보...       5
# 1  와우회원인지 몇개월 됬는데 이런 콘텐츠가 있는줄 몰랐네요~와~해리포터가 ?????리...       5
# 2  초반엔 사실 컨텐츠 부족으로 있으나 마나 였고 차치 배달 때문에 해둔거라 방치 해뒀...       5
# 3  쿠팡을 갓팡이라 하는 이유 중 하나가 바로 쿠팡플레이일 정도로 감동받으며 서비스를 ...       5
# 4  쿠팡와우 몇년 사용중인데 이거 있다는거 오늘 알았음. ㅋㅋㅋㅋㅋㅋㅋ 정말 깊은 빡침...       5
#
#                                    developerResponse  isEdited   userName  \
# 0  {'id': 26523819, 'body': '안녕하세요, 고객님. 쿠팡플레이 입니...     False      쥬니 쥬니
# 1  {'id': 29022389, 'body': '안녕하세요 bhe808 고객님, 쿠팡...     False     bhe808
# 2  {'id': 29526690, 'body': '안녕하세요 악플만 적음 고객님, 쿠팡...     False     악플만 적음
# 3  {'id': 26683481, 'body': '안녕하세요, 쿠팡플레이 입니다. 소중...     False  Chadiiiii
# 4  {'id': 26397111, 'body': '안녕하세요, 고객님. 쿠팡플레이 입니...     False      넷플사용자
#
#                                title                date
# 0                      쿠팡플레이 너무 좋아요👍 2021-11-24 00:47:10
# 1                                 최고 2022-04-05 23:14:20
# 2                              진짜 최고 2022-04-30 07:49:46
# 3             애플TV용 앱개발 좀 서둘러 부탁드려요. 2021-12-05 15:50:10
# 4  한달 배송포함 2900원에 이정도면 진짜 절.대 나쁜거 아님 2021-11-20 11:22:18

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   review             220 non-null    object
#  1   rating             220 non-null    int64
#  2   developerResponse  213 non-null    object
#  3   isEdited           220 non-null    bool
#  4   userName           220 non-null    object
#  5   title              220 non-null    object
#  6   date               220 non-null    datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), int64(1), object(4)
# memory usage: 10.7+ KB

# %%
df2.to_csv('C:\\Users\\nojis\\Desktop\\apcou.csv')
